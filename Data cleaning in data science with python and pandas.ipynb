# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import os

# %%
data = pd.read_csv("C:/Users/Acer/Dropbox/PC/Desktop/work/Python/child health.csv")

# %%
data
# Out:
#       case  bwt  gestation  parity   age  height in  height m  weight lb  \
# 0        1  120      284.0       0  27.0       62.0    1.5748      100.0
# 1        2  113      282.0       0  33.0       64.0    1.6256      135.0
# 2        3  128      279.0       0  28.0       64.0    1.6256      115.0
# 3        4  123        NaN       0  36.0       69.0    1.7526      190.0
# 4        5  108      282.0       0  23.0       67.0    1.7018      125.0
# ...    ...  ...        ...     ...   ...        ...       ...        ...
# 1231  1232  113      275.0       1  27.0       60.0    1.5240      100.0
# 1232  1233  128      265.0       0  24.0       67.0    1.7018      120.0
# 1233  1234  130      291.0       0  30.0       65.0    1.6510      150.0
# 1234  1235  125      281.0       1  21.0       65.0    1.6510      110.0
# 1235  1236  117      297.0       0  38.0       65.0    1.6510      129.0
#
#       weight kg  smoke      index
# 0     45.359200    0.0  18.290037
# ...

# %%
data.head()
# Out:
#    case  bwt  gestation  parity   age  height in  height m  weight lb  \
# 0     1  120      284.0       0  27.0       62.0    1.5748      100.0
# 1     2  113      282.0       0  33.0       64.0    1.6256      135.0
# 2     3  128      279.0       0  28.0       64.0    1.6256      115.0
# 3     4  123        NaN       0  36.0       69.0    1.7526      190.0
# 4     5  108      282.0       0  23.0       67.0    1.7018      125.0
#
#    weight kg  smoke      index
# 0   45.35920    0.0  18.290037
# 1   61.23492    0.0  23.172440
# 2   52.16308    1.0  19.739486
# 3   86.18248    0.0  28.057784
# 4   56.69900    1.0  19.577551

# %%
data.tail()
# Out:
#       case  bwt  gestation  parity   age  height in  height m  weight lb  \
# 1231  1232  113      275.0       1  27.0       60.0    1.5240      100.0
# 1232  1233  128      265.0       0  24.0       67.0    1.7018      120.0
# 1233  1234  130      291.0       0  30.0       65.0    1.6510      150.0
# 1234  1235  125      281.0       1  21.0       65.0    1.6510      110.0
# 1235  1236  117      297.0       0  38.0       65.0    1.6510      129.0
#
#       weight kg  smoke      index
# 1231  45.359200    0.0  19.529695
# 1232  54.431040    0.0  18.794449
# 1233  68.038800    1.0  24.961030
# 1234  49.895120    0.0  18.304755
# 1235  58.513368    0.0  21.466486

# %%
data.describe()
# Out:
#               case          bwt    gestation       parity          age  \
# count  1236.000000  1236.000000  1223.000000  1236.000000  1234.000000
# mean    618.500000   119.576861   279.338512     0.254854    27.255267
# std     356.946775    18.236452    16.027693     0.435956     5.781405
# min       1.000000    55.000000   148.000000     0.000000    15.000000
# 25%     309.750000   108.750000   272.000000     0.000000    23.000000
# 50%     618.500000   120.000000   280.000000     0.000000    26.000000
# 75%     927.250000   131.000000   288.000000     1.000000    31.000000
# max    1236.000000   176.000000   353.000000     1.000000    45.000000
#
#          height in     height m    weight lb    weight kg        smoke  \
# count  1214.000000  1214.000000  1200.000000  1200.000000  1226.000000
# mean     64.047776     1.626814   128.625833    58.343649     0.394780
# std       2.533409     0.064349    20.971862     9.512669     0.489003
# ...

# %% [markdown]
# # Import all files

# %%
print(os.listdir())
# Out:
# ['.ipynb_checkpoints', 'babies.csv', 'biopython-1.79 (1).tar.gz', 'child health.csv', 'Data cleaning in data science with python and pandas.ipynb', 'Data science project 2 PM.ipynb', 'Data science project Child Health.ipynb', 'Data science project1 PM.ipynb', 'get-pip.py', 'python.py', 'TotalPopulationBySex.csv', 'Untitled.ipynb', 'us-counties-recent.csv', 'weather.csv']

# %%
data = pd.read_csv("child health.csv")

# %%
data
# Out:
#       case  bwt  gestation  parity   age  height in  height m  weight lb  \
# 0        1  120      284.0       0  27.0       62.0    1.5748      100.0
# 1        2  113      282.0       0  33.0       64.0    1.6256      135.0
# 2        3  128      279.0       0  28.0       64.0    1.6256      115.0
# 3        4  123        NaN       0  36.0       69.0    1.7526      190.0
# 4        5  108      282.0       0  23.0       67.0    1.7018      125.0
# ...    ...  ...        ...     ...   ...        ...       ...        ...
# 1231  1232  113      275.0       1  27.0       60.0    1.5240      100.0
# 1232  1233  128      265.0       0  24.0       67.0    1.7018      120.0
# 1233  1234  130      291.0       0  30.0       65.0    1.6510      150.0
# 1234  1235  125      281.0       1  21.0       65.0    1.6510      110.0
# 1235  1236  117      297.0       0  38.0       65.0    1.6510      129.0
#
#       weight kg  smoke      index
# 0     45.359200    0.0  18.290037
# ...

# %%
data.isnull()
# Out:
#        case    bwt  gestation  parity    age  height in  height m  weight lb  \
# 0     False  False      False   False  False      False     False      False
# 1     False  False      False   False  False      False     False      False
# 2     False  False      False   False  False      False     False      False
# 3     False  False       True   False  False      False     False      False
# 4     False  False      False   False  False      False     False      False
# ...     ...    ...        ...     ...    ...        ...       ...        ...
# 1231  False  False      False   False  False      False     False      False
# 1232  False  False      False   False  False      False     False      False
# 1233  False  False      False   False  False      False     False      False
# 1234  False  False      False   False  False      False     False      False
# 1235  False  False      False   False  False      False     False      False
#
#       weight kg  smoke  index
# ...

# %%
data.isnull().sum()
# Out:
# case          0
# bwt           0
# gestation    13
# parity        0
# age           2
# height in    22
# height m     22
# weight lb    36
# weight kg    36
# smoke        10
# index        39
# dtype: int64

# %% [markdown]
# # Step 1: Detecting NA, N/A and na values

# %%
missing_value = ["NA", np, nan]
data = pd.read_csv("child health.csv", na_values = missing_value)

# %%
data.isnull().sum()
# Out:
# case          0
# bwt           0
# gestation    13
# parity        0
# age           2
# height in    22
# height m     22
# weight lb    36
# weight kg    36
# smoke        10
# index        39
# dtype: int64

# %%
data.isnull().any()
# Out:
# case         False
# bwt          False
# gestation     True
# parity       False
# age           True
# height in     True
# height m      True
# weight lb     True
# weight kg     True
# smoke         True
# index         True
# dtype: bool

# %%
sns.heatmap(data.isnull(), yticklabels = False, annot = True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Step 2: Lets learn how to remove this values

# %%
data.dropna()
# Out:
#       case  bwt  gestation  parity   age  height in  height m  weight lb  \
# 0        1  120      284.0       0  27.0       62.0    1.5748      100.0
# 1        2  113      282.0       0  33.0       64.0    1.6256      135.0
# 2        3  128      279.0       0  28.0       64.0    1.6256      115.0
# 4        5  108      282.0       0  23.0       67.0    1.7018      125.0
# 5        6  136      286.0       0  25.0       62.0    1.5748       93.0
# ...    ...  ...        ...     ...   ...        ...       ...        ...
# 1231  1232  113      275.0       1  27.0       60.0    1.5240      100.0
# 1232  1233  128      265.0       0  24.0       67.0    1.7018      120.0
# 1233  1234  130      291.0       0  30.0       65.0    1.6510      150.0
# 1234  1235  125      281.0       1  21.0       65.0    1.6510      110.0
# 1235  1236  117      297.0       0  38.0       65.0    1.6510      129.0
#
#       weight kg  smoke      index
# 0     45.359200    0.0  18.290037
# ...

# %%
data.dropna(how = 'all')
# Out:
#       case  bwt  gestation  parity   age  height in  height m  weight lb  \
# 0        1  120      284.0       0  27.0       62.0    1.5748      100.0
# 1        2  113      282.0       0  33.0       64.0    1.6256      135.0
# 2        3  128      279.0       0  28.0       64.0    1.6256      115.0
# 3        4  123        NaN       0  36.0       69.0    1.7526      190.0
# 4        5  108      282.0       0  23.0       67.0    1.7018      125.0
# ...    ...  ...        ...     ...   ...        ...       ...        ...
# 1231  1232  113      275.0       1  27.0       60.0    1.5240      100.0
# 1232  1233  128      265.0       0  24.0       67.0    1.7018      120.0
# 1233  1234  130      291.0       0  30.0       65.0    1.6510      150.0
# 1234  1235  125      281.0       1  21.0       65.0    1.6510      110.0
# 1235  1236  117      297.0       0  38.0       65.0    1.6510      129.0
#
#       weight kg  smoke      index
# 0     45.359200    0.0  18.290037
# ...

# %%
data.fillna(0)
# Out:
#       case  bwt  gestation  parity   age  height in  height m  weight lb  \
# 0        1  120      284.0       0  27.0       62.0    1.5748      100.0
# 1        2  113      282.0       0  33.0       64.0    1.6256      135.0
# 2        3  128      279.0       0  28.0       64.0    1.6256      115.0
# 3        4  123        0.0       0  36.0       69.0    1.7526      190.0
# 4        5  108      282.0       0  23.0       67.0    1.7018      125.0
# ...    ...  ...        ...     ...   ...        ...       ...        ...
# 1231  1232  113      275.0       1  27.0       60.0    1.5240      100.0
# 1232  1233  128      265.0       0  24.0       67.0    1.7018      120.0
# 1233  1234  130      291.0       0  30.0       65.0    1.6510      150.0
# 1234  1235  125      281.0       1  21.0       65.0    1.6510      110.0
# 1235  1236  117      297.0       0  38.0       65.0    1.6510      129.0
#
#       weight kg  smoke      index
# 0     45.359200    0.0  18.290037
# ...

# %%
data.fillna(method = 'bfill')
# Out:
#       case  bwt  gestation  parity   age  height in  height m  weight lb  \
# 0        1  120      284.0       0  27.0       62.0    1.5748      100.0
# 1        2  113      282.0       0  33.0       64.0    1.6256      135.0
# 2        3  128      279.0       0  28.0       64.0    1.6256      115.0
# 3        4  123      282.0       0  36.0       69.0    1.7526      190.0
# 4        5  108      282.0       0  23.0       67.0    1.7018      125.0
# ...    ...  ...        ...     ...   ...        ...       ...        ...
# 1231  1232  113      275.0       1  27.0       60.0    1.5240      100.0
# 1232  1233  128      265.0       0  24.0       67.0    1.7018      120.0
# 1233  1234  130      291.0       0  30.0       65.0    1.6510      150.0
# 1234  1235  125      281.0       1  21.0       65.0    1.6510      110.0
# 1235  1236  117      297.0       0  38.0       65.0    1.6510      129.0
#
#       weight kg  smoke      index
# 0     45.359200    0.0  18.290037
# ...

# %%
data.interpolate()
# Out:
#       case  bwt  gestation  parity   age  height in  height m  weight lb  \
# 0        1  120      284.0       0  27.0       62.0    1.5748      100.0
# 1        2  113      282.0       0  33.0       64.0    1.6256      135.0
# 2        3  128      279.0       0  28.0       64.0    1.6256      115.0
# 3        4  123      280.5       0  36.0       69.0    1.7526      190.0
# 4        5  108      282.0       0  23.0       67.0    1.7018      125.0
# ...    ...  ...        ...     ...   ...        ...       ...        ...
# 1231  1232  113      275.0       1  27.0       60.0    1.5240      100.0
# 1232  1233  128      265.0       0  24.0       67.0    1.7018      120.0
# 1233  1234  130      291.0       0  30.0       65.0    1.6510      150.0
# 1234  1235  125      281.0       1  21.0       65.0    1.6510      110.0
# 1235  1236  117      297.0       0  38.0       65.0    1.6510      129.0
#
#       weight kg  smoke      index
# 0     45.359200    0.0  18.290037
# ...
